# %%
if (!require("igraph")) install.packages("igraph")
library ("igraph")
# Out:
# Loading required package: igraph
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
uber_filename = 'uber_dec.txt'
DIR_PATH ="graph_data/"
UBER_DIR_PATH = "uber_data/"

# %%
path = 'uber_data/uber_dec.txt'

path
# Out:
# [1] "uber_data/uber_dec.txt"

# %%
graph= read_graph( path , format = 'ncol', directed=FALSE)

# %%
dist_arr = distances(graph, v = V(graph), to = V(graph), mode = "all")

# %%
dist_arr
# Out:
#      758     972     1197    2006    620     2652    2427    2693    610
# 758     0.00  985.38 1971.47 2689.01 2891.68 3381.64 2262.74 3594.07 3134.07
# 972   985.38    0.00 2299.63 2934.44 3491.88 3581.20 2669.82 3949.19 3649.70
# 1197 1971.47 2299.63    0.00  932.67 1529.74 1708.81 1667.95 2073.30 1679.32
# 2006 2689.01 2934.44  932.67    0.00  658.79  986.09 1044.40 1329.84  799.06
# 620  2891.68 3491.88 1529.74  658.79    0.00  720.69 1009.55  930.76  466.04
# 2652 3381.64 3581.20 1708.81  986.09  720.69    0.00 1450.72  440.62  723.76
# 2427 2262.74 2669.82 1667.95 1044.40 1009.55 1450.72    0.00 1663.07 1242.89
# 2693 3594.07 3949.19 2073.30 1329.84  930.76  440.62 1663.07    0.00  981.72
# 610  3134.07 3649.70 1679.32  799.06  466.04  723.76 1242.89  981.72    0.00
# 2653 3338.14 3587.78 1743.71 1020.05  677.19   43.50 1407.22  401.63  680.26
# 408  2223.61 2707.25 1623.94 1003.40 1187.87 1579.27  178.32 1841.39 1421.21
# ...

# %%
length(dist_arr)
# Out:
# [1] 7017201

# %%
# for ( row in 1:nrow(dist_arr)){
#     print(dist_arr[row, ])
# }

# %%
write.csv(dist_arr, "uber_data/distance_matrix.csv")

# %%
file_put_contents("uber_data/distance_matrix.txt", print_r($b, true));

# %%
fileConn<-file("uber_data/distance_matrix.txt")
write(dist_arr, fileConn)
close(fileConn)

# %%
dist_table= distance_table(g, directed=FALSE)

# %%
typeof(dist_table)
